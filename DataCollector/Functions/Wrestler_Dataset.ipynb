# %% [markdown]
# Bryan Martinez

# %%
import pandas as pd
import numpy as np

# %%
# Populating Dataset
dataset = pd.read_csv(r'C:\Users\Bryan Martinez\react\prowrestleknow\DataCollector\RawResults.csv', encoding='ISO-8859-1')
dataset.head(30)
# Out:
#    company       show  year month  day  \
# 0      WWE        Raw  2024  June    3
# 1      WWE        Raw  2024  June    3
# 2      WWE        Raw  2024  June    3
# 3      WWE        Raw  2024  June    3
# 4      WWE        Raw  2024  June    3
# 5      WWE        Raw  2024  June    3
# 6      WWE        Raw  2024  June    3
# 7      WWE        Raw  2024  June    3
# 8      WWE        NXT  2024  June    4
# 9      WWE        NXT  2024  June    4
# 10     WWE        NXT  2024  June    4
# 11     WWE        NXT  2024  June    4
# 12     WWE        NXT  2024  June    4
# 13     AEW   Dynamite  2024  June    5
# 14     AEW   Dynamite  2024  June    5
# 15     AEW   Dynamite  2024  June    5
# 16     AEW   Dynamite  2024  June    5
# 17     AEW   Dynamite  2024  June    5
# 18     TNA    iMPACT!  2024  June    6
# 19     TNA    iMPACT!  2024  June    6
# 20     TNA    iMPACT!  2024  June    6
# 21     TNA    iMPACT!  2024  June    6
# 22     TNA    iMPACT!  2024  June    6
# 23     TNA    iMPACT!  2024  June    6
# 24     WWE  SmackDown  2024  June    7
# 25     WWE  SmackDown  2024  June    7
# 26     WWE  SmackDown  2024  June    7
# 27     WWE  SmackDown  2024  June    7
# 28     AEW  Collision  2024  June    8
# 29     AEW  Collision  2024  June    8
#
#                                           competitors  \
# 0                              Ludwig Kaiser, Sheamus
# 1                              Finn Balor, Dragon Lee
# 2                             Bron Breakker, Ricochet
# 3                                Kiana James, Natalya
# 4                             Braun Strowman, Carlito
# 5   Bianca Belair, Jade Cargill, Shayna Bazler, Zo...
# 6            Akam, Rezar, Kofi Kingston, Xavier Woods
# 7                         Damian Priest, Rey Mysterio
# 8                       Jordynne Grace, Stevie Turner
# 9                               Jazmyn Nyx, Thea Hail
# 10                          Damon Kemp, Tony D'Angelo
# 11                                 Izzi Dame, Natalya
# 12  Fallon Henley, Kelani Jordan, Lash Legend, Jai...
# 13  Orange Cassidy, Kyle O'Reilly, Jay Lethal, Rey...
# 14                           Mark Briscoe, Brian Cage
# 15  Bryan Danielson, Claudio Castagnoli, Jon Moxle...
# 16                         Saraya (Paige), Mariah May
# 17                 Swerve Strickland, Roderick Strong
# 18                                Jake Something, Kon
# 19                      Gisele Shaw, Shazza McKenzzie
# 20  Trent Seven, Mike Bailey, Mustafa Ali, Campaig...
# 21                        Jordynne Grace, Allysin Kay
# 22                             AJ Francis, Laredo Kid
# 23                       Nic Nemeth, Frankie Kazarian
# 24  Bianca Belair, Jade Cargill, Candice LeRae, In...
# 25                     Grayson Waller, Johnny Gargano
# 26                           Carmelo Hayes, LA Knight
# 27  Kevin Owens, Angelo Dawkins, Montez Ford, Solo...
# 28  Wheeler Yuta, Claudio Castagnoli, Dax Harwood,...
# 29                    Kris Statlander, Robyn Renegade
#
#                                               winners          wins_by  \
# 0                                       Ludwig Kaiser          pinfall
# 1                                          Finn Balor          pinfall
# 2                                       Bron Breakker          pinfall
# 3                                         Kiana James          pinfall
# 4                                      Braun Strowman          pinfall
# 5                         Bianca Belair, Jade Cargill               DQ
# 6                                         Akam, Rezar          pinfall
# 7                                       Damian Priest          pinfall
# 8                                      Jordynne Grace          pinfall
# 9                                          Jazmyn Nyx          pinfall
# 10                                      Tony D'Angelo          pinfall
# 11                                            Natalya          pinfall
# 12                    Jaida Parker, Mia Yim, Sol Ruca          pinfall
# 13                                          Rey Fenix          pinfall
# 14                                       Mark Briscoe          pinfall
# 15  Bryan Danielson, Claudio Castagnoli, Jon Moxle...          pinfall
# 16                                     Saraya (Paige)       submission
# 17                                  Swerve Strickland          pinfall
# 18                                     Jake Something          pinfall
# 19                                        Gisele Shaw          pinfall
# 20                           Trent Seven, Mike Bailey          pinfall
# 21                                     Jordynne Grace          pinfall
# 22                                         AJ Francis          pinfall
# 23                                         Nic Nemeth          pinfall
# 24                        Bianca Belair, Jade Cargill          pinfall
# 25                                     Grayson Waller          pinfall
# 26                                          LA Knight          pinfall
# 27                  Solo Sikoa, Tama Tonga, Tonga Loa               DQ
# 28                                               none  Time Limit Draw
# 29                                    Kris Statlander          pinfall
#
#             stipulations                        on_the_line duration
# 0                   none                               none      TBD
# 1                   none                               none      TBD
# 2                   none                               none      TBD
# 3                   none                               none      TBD
# 4                   none                               none      TBD
# 5                   none                               none      TBD
# 6                   none                               none      TBD
# 7                   none                               none      TBD
# 8                   none                               none      TBD
# 9                   none                               none      TBD
# 10   British Round Rules                   NXT Hertiage Cup      TBD
# 11                  none                               none      TBD
# 12                  none                               none      TBD
# 13  Fatal Four Way Match                               none      TBD
# 14                  none                               none      TBD
# 15    8-Man Grudge Match                               none      TBD
# 16                  none                               none      TBD
# 17                  none                               none      TBD
# 18                  none                               none      TBD
# 19                  none                               none      TBD
# 20                  none                               none      TBD
# 21                  none  TNA Knockout's World Championship      TBD
# 22                  none     TNA Digital Media Championship      TBD
# 23                  none                               none      TBD
# 24                  none                               none      TBD
# 25                  none                               none      TBD
# 26                  none                               none      TBD
# 27                  none                               none      TBD
# 28                  none                               none       20
# 29                  none                               none      TBD

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['company', 'show', 'year', 'month', 'day', 'competitors', 'winners',
#        'wins_by', 'stipulations', 'on_the_line', 'duration'],
#       dtype='object')

# %%
# Checking for Null Data
dataset.isnull().sum()
# Out:
# company         0
# show            0
# year            0
# month           0
# day             0
# competitors     0
# winners         0
# wins_by         0
# stipulations    0
# on_the_line     0
# duration        0
# dtype: int64

# %% [markdown]
# #   Adding Competitors to Dataset

# %%
all_names = set()
for competitors in dataset['competitors']:
    names = competitors.split(', ')
    all_names.update(names)

# Create a new DataFrame with the competitor names
filtered_dataset = pd.DataFrame({'wrestler_name': list(all_names)})
filtered_dataset.head()
# Out:
#    wrestler_name
# 0    Trent Jordy
# 1  Bianca Belair
# 2  Shayna Bazler
# 3   Wheeler Yuta
# 4     Dante Leon

# %% [markdown]
# #   Adding to Amount of Matches Involved In

# %%
for competitors in filtered_dataset["wrestler_name"]:
    p = 1+ 1
# Out:
#   Cell In[6], line 1
#     for competitors in filtered_dataset[]:
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #   Adding to Amount of Wins Involved In

# %% [markdown]
# #   Adding to Amount of Wins Via Variety of Ways
# - pinfall, submission, dq, count out, etc.

# %% [markdown]
# # Adding Years Matches Competed from 1980 to 2024 (with # of Wins)

# %% [markdown]
# # Final Results Gets Saved to New CSV File

# %%
filtered_dataset.to_csv('./WrestlerInfo.csv', index=False, encoding='ISO-8859-1')
